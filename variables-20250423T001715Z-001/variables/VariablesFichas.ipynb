# %% [markdown]
# ![¿Que-Son-las-Variables-en-Python-y-Como-Usarlas-1.png](data:image/png;base64,...)
# **VARIABLES:**
# Una variable es un espacio en la memoria (RAM) del ordenador que se utiliza para almacenar información de un determinado tipo de datos (numérica, cadenas de texto, booleanos, listas, diccionarios. Etc). Estas variables se identifican con un nombre único y sus valores pueden cambiar.
#
# En Python es un leguaje de tipado dinamico, significa que no es necesario definir el tipo de variable antes de usarla; cuando se asigna un valor a una variable, ésta se crea. En este lenguaje de programación se declaran las variables usando el operador de asignación "=".
#
# **Ejemplo de declaración e inicialización:**
# 1. Declaración: Primero ponemos el nombre de la variable:
# cancion y agregamos el operador logico de asignacion:
# cancion =
# 2. Inicialización: Agregamos el contenido (su valor se puede cambiar):
# cancion = "amo"
# **Nota:** se pone entre (" ", comillas) el nombre de la cancion porque es una variable de tipo cadena de texto.

# %%
#DECLARACIÓN DE VARIABLES DE DIFERENTES TIPOS E IMPRESIÓN EN PYTHON

#ENTEROS (INT):
edad = 26
print("Edad:", edad)                      # Salida: Edad: 26
# Out:
# Edad: 26

# %%
#REAL (FLOAT):
estatura = 1.68
print("Estatura:", estatura )                  # Salida: Estatura: 1.68
# Out:
# Estatura: 1.68

# %%
#CADENAS DE TEXTO O CARACTER (STR)
nombre = "Anyis Torres"
print("Nombre:", nombre)                  # Salida: Nombre: Anyis Torres
# Out:
# Nombre: Anyis Torres

# %%
#BOOLEANOS (BOOL)
es_activo = True
tiene_descuento = False
print("¿Está activo?", es_activo)         # Salida: ¿Está activo? True
print("¿Tiene descuento?", tiene_descuento) # Salida: ¿Tiene descuento? False

# %%
#LISTAS (LIST)
frutas = ["manzana", "banana", "naranja"]
numeros = [1, 2, 3, 4, 5]
print("Frutas:", frutas)                  # Salida: Frutas: ['manzana', 'banana', 'naranja']
print("Números:", numeros)                # Salida: Números: [1, 2, 3, 4, 5]

# %%
#DICCIONARIOS (DICT)
persona = {
    "nombre": "Anyis",
    "edad": 26,
    "ciudad": "Arauca"
}
print("Datos de persona:", persona)       # Salida: Datos de persona: {'nombre': 'Anyis', 'edad': 26, 'ciudad': 'Arauca'}
# Out:
# Datos de persona: {'nombre': 'Anyis', 'edad': 26, 'ciudad': 'Arauca'}

# %% [markdown]
# **NOTAS:**
# 1. Usa nombres claros que indiquen el propósito de la variable. Evita nombres genéricos como x, a, temp.
# 2. Para Nombres Compuestos de variables, utiliza en Python la convención snake_case (minúsculas con guiones bajos).
# 3. No Uses Palabras Reservadas. Evita nombres que sean palabras clave de Python (if, for, while, list, str, etc.).
# 4. Constantes: Si defines valores que no deben cambiar (constantes), usa mayusculas. Ej: NUMERO_PI
# 5. Asignación Múltiple: Puedes asignar varias variables en una sola línea. Ej: a, b, c = 1 , 2 , 3
# 6. Si una variable no tiene valor, usa None en lugar de dejar basura. Ej:
# resultado = None  # Indica que aún no tiene valor.

# %% [markdown]
# [AUDIO:] https://anyistorres.github.io/fichastriangulopython/variables-20250423T001715Z-001/variables/variables.aac
